# %%
import pandas as pd
df = pd.read_csv("result/bottleneck_times.csv")
df.groupby("loss_label")[["time_gen_mats",
                          "time_data_gen",
                          "time_true_surface",
                          "time_train",
                          "time_predict"]].mean()
# Out:
#             time_gen_mats  time_data_gen  time_true_surface  time_train  \
# loss_label
# exp              0.000694       0.001023           0.000057   13.243460
# frac             0.000694       0.001023           0.000057   13.157987
# log1p            0.000694       0.001023           0.000057   13.124609
# power_0.5        0.000694       0.001023           0.000057   13.232503
# power_1          0.000694       0.001023           0.000057   13.174675
#
#             time_predict
# loss_label
# exp             2.388472
# frac            2.380652
# log1p           2.369917
# power_0.5       2.509414
# power_1         2.428996
